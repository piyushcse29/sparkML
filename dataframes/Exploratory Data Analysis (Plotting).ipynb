# %% [markdown]
# # EDA

# %% [markdown]
# Exploratory Data Analysis refers to the critical process of performing initial investigations on data so as to discover patterns,to spot anomalies,to test hypothesis and to check assumptions with the help of summary statistics and graphical representations.

# %% [markdown]
# ## Related plotting libraries

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.htm

# %% [markdown]
# https://seaborn.pydata.org/tutorial/function_overview.html

# %% [markdown]
# https://plotly.com

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
ts = pd.Series(np.random.randn(1000),index=pd.date_range('1/1/2000', periods=1000))

# %%
ts
# Out:
# 2000-01-01   -0.916221
# 2000-01-02    3.031770
# 2000-01-03   -0.500912
# 2000-01-04   -0.679537
# 2000-01-05    1.976260
#                 ...
# 2002-09-22    0.062666
# 2002-09-23   -0.225257
# 2002-09-24   -0.722218
# 2002-09-25    0.301214
# 2002-09-26   -0.856397
# Freq: D, Length: 1000, dtype: float64

# %%
ts = ts.cumsum()

# %%
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4),index=ts.index, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2000-01-01 -0.524276  1.615091  0.813810 -0.403777
# 2000-01-02 -2.029097 -1.002777 -1.350051  0.016699
# 2000-01-03 -1.500719 -0.217958 -0.840115 -0.952816
# 2000-01-04  2.053544  0.118820 -0.361747  0.128213
# 2000-01-05  0.642366  1.072350 -0.027213  0.857458
# ...              ...       ...       ...       ...
# 2002-09-22  1.246406 -0.126842 -0.759618  0.907856
# 2002-09-23  0.664254  0.172287  0.365608  0.226814
# 2002-09-24 -0.913272 -0.848635  0.007736 -0.435198
# 2002-09-25  0.141381  0.435462 -0.203996  1.956659
# 2002-09-26 -0.374151  2.649851  1.272251  0.640899
#
# [1000 rows x 4 columns]

# %%
df = df.cumsum()

# %%
df.plot();

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()

# %%
df3
# Out:
#              B          C
# 0    -0.917055  -1.294013
# 1    -2.816421  -2.199057
# 2    -2.274065  -2.730127
# 3    -4.018708  -3.076616
# 4    -4.612690  -3.736578
# ..         ...        ...
# 995 -27.971661 -46.292627
# 996 -28.045388 -46.369095
# 997 -28.334807 -45.073497
# 998 -30.672736 -44.432546
# 999 -31.268252 -45.733303
#
# [1000 rows x 2 columns]

# %%
df3['A'] = pd.Series(list(range(len(df))))

# %%
df3.plot(x='B', y='C')

# %%
df.iloc[[1,500],[1,2]].plot(kind='bar');

# %%
df.iloc[5].plot.bar()
plt.axhline(0, color='k');

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])

# %%
df2.plot.bar();

# %%
df2.plot.bar(stacked=True);

# %%
df2.plot.barh(stacked=True);

# %% [markdown]
# # Histogram

# %%
df4 = pd.DataFrame({'a': np.random.randn(1000) + 1, 'b': np.random.randn(1000),'c': np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])

# %%
df4
# Out:
#             a         b         c
# 0    1.104238  0.382467 -0.417454
# 1   -0.801688 -1.159046  0.118879
# 2    1.718267 -0.563734  0.104152
# 3    1.560440  1.386208 -0.577408
# 4    1.628894 -0.333784 -1.101951
# ..        ...       ...       ...
# 995  1.087453 -0.302468 -2.442573
# 996 -0.609161  0.033832 -1.343834
# 997  2.087657  0.835420  1.633300
# 998 -0.464563 -1.040510 -3.243417
# 999  2.037738  1.191937 -1.683684
#
# [1000 rows x 3 columns]

# %%
df4.plot.hist(alpha=0.5)

# %%
df4.plot.hist(bins=2)

# %% [markdown]
# ## Box plots

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])

# %%
df
# Out:
#           A         B         C         D         E
# 0  0.790649  0.690553  0.618540  0.896664  0.746483
# 1  0.701904  0.691666  0.655683  0.021160  0.483268
# 2  0.314692  0.739152  0.097730  0.090764  0.805002
# 3  0.166158  0.747704  0.550786  0.158646  0.343324
# 4  0.711490  0.453243  0.491831  0.886616  0.735770
# 5  0.262139  0.776453  0.868173  0.985760  0.525375
# 6  0.090251  0.650634  0.279226  0.535851  0.927640
# 7  0.285300  0.589235  0.456057  0.641216  0.757078
# 8  0.018856  0.532372  0.222620  0.428311  0.305314
# 9  0.476729  0.815633  0.365336  0.918784  0.605958

# %%
df.plot.box()

# %%
np.random.seed(1234)

# %%
df_box = pd.DataFrame(np.random.randn(50, 2))

# %%
df_box['g'] = np.random.choice(['A', 'B'], size=50)

# %%
df_box
# Out:
#            0         1  g
# 0   0.471435 -1.190976  A
# 1   1.432707 -0.312652  A
# 2  -0.720589  0.887163  B
# 3   0.859588 -0.636524  A
# 4   0.015696 -2.242685  B
# 5   1.150036  0.991946  A
# 6   0.953324 -2.021255  A
# 7  -0.334077  0.002118  A
# 8   0.405453  0.289092  A
# 9   1.321158 -1.546906  A
# 10 -0.202646 -0.655969  B
# 11  0.193421  0.553439  B
# 12  1.318152 -0.469305  B
# 13  0.675554 -1.817027  B
# 14 -0.183109  1.058969  B
# 15 -0.397840  0.337438  A
# 16  1.047579  1.045938  B
# 17  0.863717 -0.122092  B
# 18  0.124713 -0.322795  B
# 19  0.841675  2.390961  B
# 20  0.076200 -0.566446  A
# 21  0.036142 -2.074978  B
# 22  0.247792 -0.897157  B
# 23 -0.136795  0.018289  B
# 24  0.755414  0.215269  B
# 25  0.841009 -1.445810  B
# 26 -1.401973 -0.100918  A
# 27 -0.548242 -0.144620  B
# 28  0.354020 -0.035513  B
# 29  0.565738  1.545659  A
# 30 -0.974236 -0.070345  B
# 31  0.307969 -0.208499  A
# 32  1.033801 -2.400454  A
# 33  2.030604 -1.142631  A
# 34  0.211883  0.704721  A
# 35 -0.785435  0.462060  B
# 36  0.704228  0.523508  B
# 37 -0.926254  2.007843  B
# 38  0.226963 -1.152659  B
# 39  0.631979  0.039513  B
# 40  0.464392 -3.563517  A
# 41  1.321106  0.152631  B
# 42  0.164530 -0.430096  A
# 43  0.767369  0.984920  A
# 44  0.270836  1.391986  A
# 45  0.079842 -0.399965  B
# 46 -1.027851 -0.584718  B
# 47  0.816594 -0.081947  B
# 48 -0.344766  0.528288  A
# 49 -1.068989 -0.511881  A

# %%
df_box.loc[df_box['g'] == 'B', 1] += 3

# %%
df_box
# Out:
#            0         1  g
# 0   0.471435 -1.190976  A
# 1   1.432707 -0.312652  A
# 2  -0.720589  3.887163  B
# 3   0.859588 -0.636524  A
# 4   0.015696  0.757315  B
# 5   1.150036  0.991946  A
# 6   0.953324 -2.021255  A
# 7  -0.334077  0.002118  A
# 8   0.405453  0.289092  A
# 9   1.321158 -1.546906  A
# 10 -0.202646  2.344031  B
# 11  0.193421  3.553439  B
# 12  1.318152  2.530695  B
# 13  0.675554  1.182973  B
# 14 -0.183109  4.058969  B
# 15 -0.397840  0.337438  A
# 16  1.047579  4.045938  B
# 17  0.863717  2.877908  B
# 18  0.124713  2.677205  B
# 19  0.841675  5.390961  B
# 20  0.076200 -0.566446  A
# 21  0.036142  0.925022  B
# 22  0.247792  2.102843  B
# 23 -0.136795  3.018289  B
# 24  0.755414  3.215269  B
# 25  0.841009  1.554190  B
# 26 -1.401973 -0.100918  A
# 27 -0.548242  2.855380  B
# 28  0.354020  2.964487  B
# 29  0.565738  1.545659  A
# 30 -0.974236  2.929655  B
# 31  0.307969 -0.208499  A
# 32  1.033801 -2.400454  A
# 33  2.030604 -1.142631  A
# 34  0.211883  0.704721  A
# 35 -0.785435  3.462060  B
# 36  0.704228  3.523508  B
# 37 -0.926254  5.007843  B
# 38  0.226963  1.847341  B
# 39  0.631979  3.039513  B
# 40  0.464392 -3.563517  A
# 41  1.321106  3.152631  B
# 42  0.164530 -0.430096  A
# 43  0.767369  0.984920  A
# 44  0.270836  1.391986  A
# 45  0.079842  2.600035  B
# 46 -1.027851  2.415282  B
# 47  0.816594  2.918053  B
# 48 -0.344766  0.528288  A
# 49 -1.068989 -0.511881  A

# %%
bp = df_box.boxplot(by='g')
# Out:
# /Users/piyushmittal/anaconda3/envs/spark-demo/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /Users/piyushmittal/anaconda3/envs/spark-demo/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ## Area Plot

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])

# %%
df
# Out:
#           a         b         c         d
# 0  0.556895  0.084774  0.333002  0.728429
# 1  0.142435  0.552469  0.273043  0.974495
# 2  0.667787  0.255653  0.108311  0.776181
# 3  0.782478  0.761604  0.914403  0.658623
# 4  0.568368  0.201756  0.698296  0.952195
# 5  0.889963  0.993567  0.818704  0.545122
# 6  0.451254  0.890557  0.973265  0.593411
# 7  0.366074  0.323095  0.871423  0.215634
# 8  0.734945  0.365619  0.801603  0.782736
# 9  0.701355  0.622777  0.493683  0.840538

# %%
df.plot.area();

# %%
df.plot.area(stacked=False);

# %% [markdown]
# ## Scatter plot

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])

# %%
df.plot.scatter(x='a', y='b');

# %% [markdown]
# ## Scatter matrix plot

# %%
from pandas.plotting import scatter_matrix

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])

# %%
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde');
